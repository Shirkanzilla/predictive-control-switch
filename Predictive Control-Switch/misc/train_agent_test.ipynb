# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
print("Current device:", torch.cuda.current_device())
print("Device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# CUDA available: True
# CUDA device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060

# %%
import mujoco
model = mujoco.MjModel.from_xml_string("""
<mujoco>
  <worldbody>
    <light pos="0 0 10"/>
    <geom type="plane" size="10 10 0.1"/>
    <body pos="0 0 1">
      <geom type="sphere" size="0.1"/>
    </body>
  </worldbody>
</mujoco>
""")
data = mujoco.MjData(model)
print("MuJoCo simulation loaded!")
# Out:
# MuJoCo simulation loaded!

# %%
import os
os.environ['LD_LIBRARY_PATH'] = '/home/user/.mujoco/mujoco210/bin'

# %%
import safety_gymnasium

env = safety_gymnasium.make("SafetyPointGoal1-v0")
# Out:
# Import error. Trying to rebuild mujoco_py.
# running build_ext
# building 'mujoco_py.cymj' extension
# x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -Wdate-time -D_FORTIFY_SOURCE=3 -fPIC -I/home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py -I/home/user/.mujoco/mujoco210/include -I/home/user/bachelor/RL/lib/python3.8/site-packages/numpy/core/include -I/home/user/bachelor/RL/include -I/usr/include/python3.8 -c /home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/cymj.c -o /home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/cymj.o -fopenmp -w
# x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -Wdate-time -D_FORTIFY_SOURCE=3 -fPIC -I/home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py -I/home/user/.mujoco/mujoco210/include -I/home/user/bachelor/RL/lib/python3.8/site-packages/numpy/core/include -I/home/user/bachelor/RL/include -I/usr/include/python3.8 -c /home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/gl/osmesashim.c -o /home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/gl/osmesashim.o -fopenmp -w
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -Wdate-time -D_FORTIFY_SOURCE=3 -fPIC /home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/cymj.o /home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/gl/osmesashim.o -L/home/user/.mujoco/mujoco210/bin -Wl,--enable-new-dtags,-R/home/user/.mujoco/mujoco210/bin -lmujoco210 -lglewosmesa -lOSMesa -lGL -o /home/user/bachelor/RL/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/lib.linux-x86_64-3.8/mujoco_py/cymj.cpython-38-x86_64-linux-gnu.so -fopenmp

# %% [markdown]
# # Train an initial agent with PPO and the Goal1 Setting to see how long it takes

# %%
from tqdm.notebook import tqdm

# %%
import omnisafe

env_id = 'SafetyPointGoal1-v0'
# Train for 100 epochs (default steps is 20.000, so i lowered the total steps from 10.000.000 to 2.000.000)
custom_cfgs = {
    'train_cfgs': {
        'total_steps': 2000000,
    },


}

agent = omnisafe.Agent("PPO", env_id=env_id, custom_cfgs=custom_cfgs)
agent.learn()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import omnisafe
#       3 env_id = 'SafetyPointGoal1-v0'
#       4 # Train for 100 epochs (default steps is 20.000, so i lowered the total steps from 10.000.000 to 2.000.000)
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/__init__.py:17
#       1 # Copyright 2023 OmniSafe Team. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """OmniSafe: A comprehensive and reliable benchmark for safe reinforcement learning."""
# ---> 17 from omnisafe import algorithms
#      18 from omnisafe.algorithms import ALGORITHMS
#      19 from omnisafe.algorithms.algo_wrapper import AlgoWrapper as Agent
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/algorithms/__init__.py:20
#      17 import itertools
#      18 from types import MappingProxyType
# ---> 20 from omnisafe.algorithms import model_based, off_policy, offline, on_policy
#      21 from omnisafe.algorithms.base_algo import BaseAlgo
#      23 # Model-based Safe
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/algorithms/model_based/__init__.py:17
#       1 # Copyright 2023 OmniSafe Team. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Model-Based algorithms."""
# ---> 17 from omnisafe.algorithms.model_based import base
#      18 from omnisafe.algorithms.model_based.base import LOOP, PETS
#      19 from omnisafe.algorithms.model_based.cap_pets import CAPPETS
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/algorithms/model_based/base/__init__.py:17
#       1 # Copyright 2023 OmniSafe Team. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Basic Model Based Reinforcement Learning algorithms."""
# ---> 17 from omnisafe.algorithms.model_based.base.loop import LOOP
#      18 from omnisafe.algorithms.model_based.base.pets import PETS
#      21 __all__ = ['LOOP', 'PETS']
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/algorithms/model_based/base/loop.py:29
#      27 from omnisafe.algorithms import registry
#      28 from omnisafe.algorithms.model_based.base.ensemble import EnsembleDynamicsModel
# ---> 29 from omnisafe.algorithms.model_based.base.pets import PETS
#      30 from omnisafe.algorithms.model_based.planner.arc import ARCPlanner
#      31 from omnisafe.common.buffer import OffPolicyBuffer
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/algorithms/model_based/base/pets.py:30
#      27 from gymnasium.utils.save_video import save_video
#      28 from matplotlib import pylab
# ---> 30 from omnisafe.adapter import ModelBasedAdapter
#      31 from omnisafe.algorithms import registry
#      32 from omnisafe.algorithms.base_algo import BaseAlgo
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/adapter/__init__.py:17
#       1 # Copyright 2023 OmniSafe Team. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Adapter for the environment and the algorithm."""
# ---> 17 from omnisafe.adapter.early_terminated_adapter import EarlyTerminatedAdapter
#      18 from omnisafe.adapter.modelbased_adapter import ModelBasedAdapter
#      19 from omnisafe.adapter.offline_adapter import OfflineAdapter
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/adapter/early_terminated_adapter.py:23
#      19 from typing import Any
#      21 import torch
# ---> 23 from omnisafe.adapter.onpolicy_adapter import OnPolicyAdapter
#      24 from omnisafe.utils.config import Config
#      27 class EarlyTerminatedAdapter(OnPolicyAdapter):
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/adapter/onpolicy_adapter.py:24
#      21 import torch
#      22 from rich.progress import track
# ---> 24 from omnisafe.adapter.online_adapter import OnlineAdapter
#      25 from omnisafe.common.buffer import VectorOnPolicyBuffer
#      26 from omnisafe.common.logger import Logger
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/adapter/online_adapter.py:23
#      19 from typing import Any
#      21 import torch
# ---> 23 from omnisafe.envs.core import CMDP, make, support_envs
#      24 from omnisafe.envs.wrapper import (
#      25     ActionScale,
#      26     AutoReset,
#    (...)
#      31     Unsqueeze,
#      32 )
#      33 from omnisafe.typing import OmnisafeSpace
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/envs/__init__.py:18
#      15 """Environment API for OmniSafe."""
#      17 from omnisafe.envs.core import CMDP, env_register, make, support_envs
# ---> 18 from omnisafe.envs.custom_env import CustomEnv
#      19 from omnisafe.envs.mujoco_env import MujocoEnv
#      20 from omnisafe.envs.safety_gymnasium_env import SafetyGymnasiumEnv
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/envs/custom_env.py:26
#      23 import torch
#      24 from gymnasium import spaces
# ---> 26 from omnisafe.common.logger import Logger
#      27 from omnisafe.envs.core import CMDP, env_register
#      28 from omnisafe.typing import OmnisafeSpace
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/common/__init__.py:18
#      15 """Common Common utilities for OmniSafe."""
#      17 from omnisafe.common.lagrange import Lagrange
# ---> 18 from omnisafe.common.logger import Logger
#      19 from omnisafe.common.normalizer import Normalizer
#      20 from omnisafe.common.pid_lagrange import PIDLagrangian
#
# File ~/bachelor/RL/lib/python3.8/site-packages/omnisafe/common/logger.py:28
#      26 import numpy as np
#      27 import torch
# ---> 28 import wandb
#      29 from rich import print  # pylint: disable=redefined-builtin,wrong-import-order
#      30 from rich.console import Console  # pylint: disable=wrong-import-order
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/__init__.py:22
#      19 from wandb.errors.term import termsetup, termlog, termerror, termwarn
#      21 # Configure the logger as early as possible for consistent behavior.
# ---> 22 from wandb.sdk.lib import wb_logging as _wb_logging
#      23 _wb_logging.configure_wandb_logger()
#      25 from wandb import sdk as wandb_sdk
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/sdk/__init__.py:25
#       3 __all__ = (
#       4     "Config",
#       5     "Settings",
#    (...)
#      21     "helper",
#      22 )
#      24 from . import wandb_helper as helper
# ---> 25 from .artifacts.artifact import Artifact
#      26 from .wandb_alerts import AlertLevel
#      27 from .wandb_config import Config
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/sdk/artifacts/artifact.py:28
#      25 import requests
#      27 import wandb
# ---> 28 from wandb import data_types, env, util
#      29 from wandb.apis.normalize import normalize_exceptions
#      30 from wandb.apis.public import ArtifactCollection, ArtifactFiles, RetryingClient, Run
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/data_types.py:16
#       1 """This module defines data types for logging rich, interactive visualizations to W&B.
#       2
#       3 Data types include common media types, like images, audio, and videos,
#    (...)
#      13 and upload them to the W&B server.
#      14 """
# ---> 16 from .sdk.data_types.audio import Audio
#      17 from .sdk.data_types.base_types.media import BatchableMedia, Media
#      18 from .sdk.data_types.base_types.wb_value import WBValue
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/sdk/data_types/audio.py:10
#       8 from . import _dtypes
#       9 from ._private import MEDIA_TMP
# ---> 10 from .base_types.media import BatchableMedia
#      13 class Audio(BatchableMedia):
#      14     """Wandb class for audio clips.
#      15
#      16     Args:
#    (...)
#      21         caption: (string) Caption to display with audio.
#      22     """
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/sdk/data_types/base_types/media.py:13
#      10 from wandb.sdk.lib import filesystem
#      11 from wandb.sdk.lib.paths import LogicalPath
# ---> 13 from .wb_value import WBValue
#      15 if TYPE_CHECKING:  # pragma: no cover
#      16     import numpy as np
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/sdk/data_types/base_types/wb_value.py:4
#       1 from typing import TYPE_CHECKING, Any, ClassVar, Dict, List, Optional, Type, Union
#       3 from wandb import util
# ----> 4 from wandb.sdk import wandb_setup
#       6 if TYPE_CHECKING:  # pragma: no cover
#       7     from wandb.sdk.artifacts.artifact import Artifact
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/sdk/wandb_setup.py:26
#      23 import wandb.integration.sagemaker as sagemaker
#      24 from wandb.sdk.lib import import_hooks, wb_logging
# ---> 26 from . import wandb_settings
#      27 from .lib import config_util, server
#      29 if TYPE_CHECKING:
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/sdk/wandb_settings.py:29
#      27 import wandb
#      28 from wandb import env, termwarn, util
# ---> 29 from wandb._pydantic import (
#      30     IS_PYDANTIC_V2,
#      31     AliasChoices,
#      32     computed_field,
#      33     field_validator,
#      34     model_validator,
#      35 )
#      36 from wandb.errors import UsageError
#      37 from wandb.proto import wandb_settings_pb2
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/_pydantic/__init__.py:3
#       1 """Internal utilities for working with pydantic."""
# ----> 3 from .base import (
#       4     Base,
#       5     CompatBaseModel,
#       6     GQLBase,
#       7     GQLId,
#       8     SerializedToJson,
#       9     Typename,
#      10     ensure_json,
#      11 )
#      12 from .utils import IS_PYDANTIC_V2, pydantic_isinstance, to_json
#      13 from .v1_compat import AliasChoices, computed_field, field_validator, model_validator
#
# File ~/bachelor/RL/lib/python3.8/site-packages/wandb/_pydantic/base.py:47
#      42     __doc__ = None  # Prevent subclasses from inheriting the BaseModel docstring
#      45 # Base class for all generated classes/types.
#      46 # Omitted from docstring to avoid inclusion in generated docs.
# ---> 47 class Base(CompatBaseModel):
#      48     model_config = ConfigDict(
#      49         populate_by_name=True,
#      50         validate_assignment=True,
#    (...)
#      55         revalidate_instances="always",
#      56     )
#      58     @override
#      59     def model_dump(
#      60         self,
#    (...)
#      63         **kwargs: Unpack[ModelDumpKwargs],
#      64     ) -> dict[str, Any]:
#
# File ~/bachelor/RL/lib/python3.8/site-packages/pydantic/_internal/_model_construction.py:219, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     215     parent_namespace = unpack_lenient_weakvaluedict(parent_namespace)
#     217 ns_resolver = NsResolver(parent_namespace=parent_namespace)
# --> 219 set_model_fields(cls, bases, config_wrapper, ns_resolver)
#     221 if config_wrapper.frozen and '__hash__' not in namespace:
#     222     set_default_hash_func(cls, bases)
#
# File ~/bachelor/RL/lib/python3.8/site-packages/pydantic/_internal/_model_construction.py:537, in set_model_fields(cls, bases, config_wrapper, ns_resolver)
#     528 """Collect and set `cls.__pydantic_fields__` and `cls.__class_vars__`.
#     529
#     530 Args:
#    (...)
#     534     ns_resolver: Namespace resolver to use when getting model annotations.
#     535 """
#     536 typevars_map = get_model_typevars_map(cls)
# --> 537 fields, class_vars = collect_model_fields(cls, bases, config_wrapper, ns_resolver, typevars_map=typevars_map)
#     539 cls.__pydantic_fields__ = fields
#     540 cls.__class_vars__.update(class_vars)
#
# File ~/bachelor/RL/lib/python3.8/site-packages/pydantic/_internal/_fields.py:249, in collect_model_fields(cls, bases, config_wrapper, ns_resolver, typevars_map)
#     246     for field in fields.values():
#     247         field.apply_typevars_map(typevars_map)
# --> 249 _update_fields_from_docstrings(cls, fields, config_wrapper)
#     250 return fields, class_vars
#
# File ~/bachelor/RL/lib/python3.8/site-packages/pydantic/_internal/_fields.py:68, in _update_fields_from_docstrings(cls, fields, config_wrapper)
#      66 def _update_fields_from_docstrings(cls: type[Any], fields: dict[str, FieldInfo], config_wrapper: ConfigWrapper) -> None:
#      67     if config_wrapper.use_attribute_docstrings:
# ---> 68         fields_docs = extract_docstrings_from_cls(cls)
#      69         for ann_name, field_info in fields.items():
#      70             if field_info.description is None and ann_name in fields_docs:
#
# File ~/bachelor/RL/lib/python3.8/site-packages/pydantic/_internal/_docs_extraction.py:99, in extract_docstrings_from_cls(cls, use_inspect)
#      97         return {}
#      98 else:
# ---> 99     source = _extract_source_from_frame(cls)
#     101 if not source:
#     102     return {}
#
# File ~/bachelor/RL/lib/python3.8/site-packages/pydantic/_internal/_docs_extraction.py:55, in _extract_source_from_frame(cls)
#      52 frame = inspect.currentframe()
#      54 while frame:
# ---> 55     if inspect.getmodule(frame) is inspect.getmodule(cls):
#      56         lnum = frame.f_lineno
#      57         try:
#
# File /usr/lib/python3.8/inspect.py:754, in getmodule(object, _filename)
#     751         f = getabsfile(module)
#     752         # Always map to the name the module knows itself by
#     753         modulesbyfile[f] = modulesbyfile[
# --> 754             os.path.realpath(f)] = module.__name__
#     755 if file in modulesbyfile:
#     756     return sys.modules.get(modulesbyfile[file])
#
# File /usr/lib/python3.8/posixpath.py:391, in realpath(filename)
#     388     """Return the canonical path of the specified filename, eliminating any
#     389 symbolic links encountered in the path."""
#     390     filename = os.fspath(filename)
# --> 391     path, ok = _joinrealpath(filename[:0], filename, {})
#     392     return abspath(path)
#
# File /usr/lib/python3.8/posixpath.py:425, in _joinrealpath(path, rest, seen)
#     423     continue
#     424 newpath = join(path, name)
# --> 425 if not islink(newpath):
#     426     path = newpath
#     427     continue
#
# File /usr/lib/python3.8/posixpath.py:167, in islink(path)
#     165 """Test whether a path is a symbolic link"""
#     166 try:
# --> 167     st = os.lstat(path)
#     168 except (OSError, ValueError, AttributeError):
#     169     return False
#
# KeyboardInterrupt:

# %% [markdown]
# # Train agent with PPOLag and save trajectories to create a dataset

# %%
import omnisafe
env_id = 'SafetyPointGoal1-v0'
# Train for 100 epochs (default steps is 20.000, so i lowered the total steps from 10.000.000 to 2.000.000)
custom_cfgs = {
    'train_cfgs': {
        'total_steps': 20000,
    },
    'lagrange_cfgs': {
        'cost_limit' : 25.0 # define cost budget (default is 25)
    }
}

agent = omnisafe.Agent("PPOLag", env_id=env_id, custom_cfgs=custom_cfgs)
reward, cost, epoch_len = agent.learn()
# Out:
# Loading PPOLag.yaml from /home/user/bachelor/RL/lib/python3.8/site-packages/omnisafe/utils/../configs/on-policy/PPOLag.yaml
# Logging data to ./runs/PPOLag-{SafetyPointGoal1-v0}/seed-000-2025-05-14-15-45-47/progress.csv
# Save with config in config.json
# INFO: Start training
# Output()
# Warning: trajectory cut off when rollout by epoch at 1000.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ -0.1470714509487152   │
# │ Metrics/EpCost                 │ 77.6500015258789      │
# │ Metrics/EpLen                  │ 1000.0                │
# │ Train/Epoch                    │ 0.0                   │
# │ Train/Entropy                  │ 1.4114770889282227    │
# │ Train/KL                       │ 0.014944086782634258  │
# │ Train/StopIter                 │ 40.0                  │
# │ Train/PolicyRatio/Mean         │ 0.9989596605300903    │
# │ Train/PolicyRatio/Min          │ 0.9989596605300903    │
# │ Train/PolicyRatio/Max          │ 0.9989596605300903    │
# │ Train/PolicyRatio/Std          │ 0.018994012847542763  │
# │ Train/LR                       │ 0.0                   │
# │ Train/PolicyStd                │ 0.9925696849822998    │
# │ TotalEnvSteps                  │ 20000.0               │
# │ Loss/Loss_pi                   │ -0.015867583453655243 │
# │ Loss/Loss_pi/Delta             │ -0.015867583453655243 │
# │ Value/Adv                      │ 0.2004450261592865    │
# │ Loss/Loss_reward_critic        │ 0.004908934701234102  │
# │ Loss/Loss_reward_critic/Delta  │ 0.004908934701234102  │
# │ Value/reward                   │ 0.021773381158709526  │
# │ Loss/Loss_cost_critic          │ 2.247427463531494     │
# │ Loss/Loss_cost_critic/Delta    │ 2.247427463531494     │
# │ Value/cost                     │ -0.13317905366420746  │
# │ Time/Total                     │ 117.22892761230469    │
# │ Time/Rollout                   │ 46.375186920166016    │
# │ Time/Update                    │ 70.8530502319336      │
# │ Time/Epoch                     │ 117.228271484375      │
# │ Time/FPS                       │ 170.60731506347656    │
# │ Metrics/LagrangeMultiplier/Mea │ 0.03599999472498894   │
# │ Metrics/LagrangeMultiplier/Min │ 0.03599999472498894   │
# │ Metrics/LagrangeMultiplier/Max │ 0.03599999472498894   │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                   │
# └────────────────────────────────┴───────────────────────┘

# %%
import gymnasium as gym
import torch
import numpy as np
import pickle

from omnisafe.adapter.onpolicy_adapter import OnPolicyAdapter
from omnisafe.models import ActorCriticPPO
from omnisafe.utils.config import Config

# === Lade Config & Environment ===
config_path = 'runs/ppo_lagrangian/SafetyPointGoal1-v0/seed-000/config.yaml'
cfg = Config(config_path)
env = gym.make(cfg.task, render_mode=None)

# === Lade trainiertes Modell ===
model = ActorCriticPPO(cfg.obs_space, cfg.act_space, cfg)
model.load_checkpoint(f"{cfg.log_dir}/torch_save/model.pt")

# === Prepare Adapter ===
adapter = OnPolicyAdapter(env, cfg)

# === Dataset sammeln ===
dataset = []
num_episodes = 20

for ep in range(num_episodes):
    obs, _ = env.reset()
    done = False
    traj = []
    costs = []

    while not done:
        obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
        action, _, _ = model.explore(obs_tensor)
        action = action.squeeze(0).detach().numpy()

        next_obs, reward, terminated, truncated, info = env.step(action)
        cost = info.get("cost", 0.0)

        traj.append(obs)
        costs.append(cost)
        obs = next_obs
        done = terminated or truncated

    # Expected future cost
    for t in range(len(traj)):
        state = traj[t]
        future_cost = sum(costs[t:])
        dataset.append((state, future_cost))

# === Speichern ===
with open("expected_cost_dataset.pkl", "wb") as f:
    pickle.dump(dataset, f)

print(f"Gespeichert: {len(dataset)} Einträge.")

# %%
print(reward, cost, epoch_len)
# Out:
# -0.1470714509487152 77.6500015258789 1000.0
